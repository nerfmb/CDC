# %%
#http://tour-pedia.org/api/getReviews?parameters

# %%
import requests
import json
import pandas as pd
#example api request
#http://tour-pedia.org/api/getReviews?location=Rome&startDate=1-8-2013&endDate=31-8-2013&keyword=swimming+pool


#response = requests.get("http://tour-pedia.org/api/getReviews?language=en")
#print(response.status_code)

# %%
#accomodation, attraction, restaurant

#response = requests.get("http://tour-pedia.org/api/getReviews?location=Rome&category=accomodation&startDate=28-9-2023&minWords=63")
response = requests.get("http://tour-pedia.org/api/getReviews?location=Rome&language=en")

data = response.json()

# %%
for i in range(len(data)):
    data[i]['location'] = 'Rome'

# %%
data
# Out:
# [{'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Hot water. Book online. 5 Euro deposit for key, pay upon arrival.',
#   'time': '2009-12-15',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062becf',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'pasta party is nice, be there on time.8 bed dorm? open a window before sleeping..',
#   'time': '2010-12-19',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed0',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Wi-Fi works way better near the reception desk',
#   'time': '2011-01-31',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed1',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Alessandro Downtown Hostels is a budget accommodation situated in the centre of Rome, 5 minute walking distance from Termini station!',
#   'time': '2011-06-21',
#   'wordsCount': 19,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed2',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'A city for the sights - Claudia (England)',
#   'time': '2011-06-28',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed3',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'You can come here and enjoy your trip. - KYEONG KU, (South Korea)',
#   'time': '2011-08-05',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed4',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The restaurant the staff recommended for traditional home-made pasta is really good. You should definitely try it! - Yibi, (England & Wales)',
#   'time': '2011-08-05',
#   'wordsCount': 21,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed5',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'They have a shared kitchen with plenty of fridge space to cook your own meals cheaply. - Abbie, (England & Wales)',
#   'time': '2011-08-05',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed6',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The walking tours which are organised by the hostel. Peter (the guide) is just great - Sharath (Saudi Arabia)',
#   'time': '2011-08-05',
#   'wordsCount': 19,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed7',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Pillows must be softer not nice to sleep on. Good location.for the price.',
#   'time': '2011-12-12',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bed9',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': '25€ per night for 8 bed dorm~room...wifi isnt that good at 3rd and 4th floor!',
#   'time': '2012-05-11',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062beda',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 8,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Very well positioned at about 20 mins walking distance from the Colloseum. Great hosts, it's the kind of place where you really have fun and meet interesting travelers.",
#   'time': '2012-07-18',
#   'wordsCount': 27,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bedb',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Pasta Party is great! Free pasta on Teusday :)',
#   'time': '2012-09-18',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bedc',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Free pasta party on Tue 8:30pm! Save a meal!',
#   'time': '2012-09-18',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bedd',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice. Clean bathrooms,wifi included,sheets',
#   'time': '2013-03-04',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bede',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Internet doesn't work really well. You have To connect to WiFi every time that your Phone is blocked/unblocked",
#   'time': '2013-05-07',
#   'wordsCount': 19,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bee0',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Thumb up just like for #AlessandroPalace!',
#   'time': '2013-09-27',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e4ae9eef5a5062bee3',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Good value for the money. The area is great, very conveniently located near the Termini station. Friendly staff and free wifi! What else do you need? :-))',
#   'time': '2011-09-22',
#   'wordsCount': 27,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e7ae9eef5a5062c261',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Use tripadvisor to get to the best restaurants in town!',
#   'time': '2012-06-02',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e7ae9eef5a5062c262',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The beds are uncomfortable and the rooms smell bad. The wifi is shitty and there are so many stairs. Go somewhere else.',
#   'time': '2013-05-29',
#   'wordsCount': 22,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e7ae9eef5a5062c263',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Front desk agent was rude, so we decided not to stay here.',
#   'time': '2013-06-05',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e7ae9eef5a5062c264',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Wi-fi only for one device',
#   'time': '2013-07-14',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e7ae9eef5a5062c266',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Close to villa Borghese and Spanisch Stairs. Great HQ for Roms visit',
#   'time': '2013-06-23',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e8ae9eef5a5062c30c',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great functional apartments, good localization and service! Would definitely come back!',
#   'time': '2012-05-08',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e8ae9eef5a5062c310',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Frendly personal, free wi-fi, vending machine with cheep price for mineral water, cola and snacks. Situated near Termini station, 10 minute by foot',
#   'time': '2013-06-29',
#   'wordsCount': 22,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731e9ae9eef5a5062c4ca',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Good breakfast!',
#   'time': '2011-03-05',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c566',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The beer is expensive as is the buffet... Better to go into Rome...',
#   'time': '2011-04-14',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c567',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Free in - room wired connection BUT!!!! free WiFi @ Lobby... Poorrrrr B-(',
#   'time': '2011-05-06',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c568',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Fridge doesn't work, no drinking water,no tea,coffee&hot cup, and no ice machine!",
#   'time': '2011-05-06',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c569',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 2,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "18 euro cheeseburger- overpriced and didn't come with the bacon that probably accounted for 5 euro of the price. Also, shower doesn't drain well. Service is Poor at times, rude lady in ex. Lounge.",
#   'time': '2011-06-20',
#   'wordsCount': 32,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c56a',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'hufff...nice place....',
#   'time': '2011-07-01',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c56b',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Bad location, overpriced, only good for big events',
#   'time': '2012-08-05',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c56d',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Fast Free Wifi, room is comfortable and modern system with electronic card-it's key for room and elevator",
#   'time': '2012-10-10',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c56e',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Impressive and stylish decoration',
#   'time': '2012-12-07',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c56f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Don't go there.",
#   'time': '2013-02-03',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c570',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "It's a great thing that the hotel shuttle bus drove to the city center and back with only 1 passenger: me! Great service, bravo!",
#   'time': '2013-03-17',
#   'wordsCount': 23,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c571',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Beautiful lobby, nice room, no shower curtain but nice towel warmer.  Expensive, but it's Rome.  A bit outside the city but convenient shuttle.",
#   'time': '2013-05-07',
#   'wordsCount': 23,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c572',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Make sure you have time, cause they take theirs. Thanks Mom! For all the Marriott stays.',
#   'time': '2013-06-25',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c573',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 2,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'You need hours to wait for someone at reception. But staff is nice! Room is great, no shower curtain in the bath. Parking in hotel 12€ per day. It takes about 20min to get to the city from there.',
#   'time': '2013-06-30',
#   'wordsCount': 38,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c574',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 2,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'This Hotel is perfecto but is fuckıng far from centre and taxi is coming for 40 euro.You you want to come here in summer and like walking,you need another hotel.',
#   'time': '2013-07-13',
#   'wordsCount': 32,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c575',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Quite abrasive service at breakfast. Speak italian or die :(',
#   'time': '2013-08-27',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c576',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Staff at breakfast appears to be more interested in idle chats than customers. Alternatively stroll between tables with burly security thug approach and respond to customers with dismissive weave.',
#   'time': '2013-08-29',
#   'wordsCount': 29,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c577',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Entrance hall',
#   'time': '2013-11-08',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731eaae9eef5a5062c57a',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Free WIFI throughout the hotel. Friendly staff. But he rooms are outdated and the airco doesn't work properly. In the summertime the rooms are too hot",
#   'time': '2013-04-19',
#   'wordsCount': 26,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731ecae9eef5a5062c7b5',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Large rooms for Europe. Very clean, nice pool, great breakfast and free wifi. A little far from everything, but I think the above makes up for it!',
#   'time': '2013-06-29',
#   'wordsCount': 27,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731ecae9eef5a5062c7b6',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 8,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': '+ Luxurious hotel + Free Wi-Fi + Swimming pool, solarium and gym + Helpful staff - Outdated decor in rooms - Staff are sometimes stiff - Some elevators do not work properly',
#   'time': '2013-08-21',
#   'wordsCount': 28,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731ecae9eef5a5062c7b7',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Go to the supermarket to stock up on beer and put them into the fridge in your room.',
#   'time': '2010-10-22',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73222ae9eef5a5062dfcf',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Don't expect any help form front desk",
#   'time': '2011-11-13',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73222ae9eef5a5062dfd0',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'bad hotel, beautiful Serbyan Girls hosted here!',
#   'time': '2012-01-03',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73222ae9eef5a5062dfd1',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'A fake 4 stars hotel in the middle of nowhere. There where pigeons in the breakfast room, no internet connection, manfunctioning toilets in the room... Worst hotel ever!',
#   'time': '2012-01-06',
#   'wordsCount': 27,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73222ae9eef5a5062dfd2',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Stay away from here:uncomfortable,very isolated, no park around, no welness area, not available jym, internet service doesn't work well,staff doesn't speak english, breakfast only with coffee machine.",
#   'time': '2012-01-07',
#   'wordsCount': 30,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73222ae9eef5a5062dfd3',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'CADÊ TODDYINHO?',
#   'time': '2012-09-09',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73222ae9eef5a5062dfe6',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 2,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'a bit too far out from the city form me, and unfortunately being wheelchair bound this made everything extremely difficult, ending up in having to move hostel... although the hostel itself was perfect',
#   'time': '2013-10-24',
#   'wordsCount': 33,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73228ae9eef5a5062e236',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'huge rooms and nice staff !',
#   'time': '2012-06-12',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73229ae9eef5a5062e302',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Rooms at floor 1 have view like this:',
#   'time': '2013-10-03',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73229ae9eef5a5062e304',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Check out',
#   'time': '2010-04-16',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4e8',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Don't order room service and take the shuttle",
#   'time': '2010-04-16',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4e9',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Gasp-worthy views of rome',
#   'time': '2010-06-01',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4ea',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Overlooking the panorama that has inspired visitors for centuries is Rome's most prestigious address. Though only minutes from the city's great monuments, the Rome Cavalieri has the tranquillity of an",
#   'time': '2010-08-14',
#   'wordsCount': 30,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4ec',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Try the 40€ Club sandwich..',
#   'time': '2010-11-18',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4ee',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Just the most spectacular views.',
#   'time': '2011-04-29',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4f0',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The Club sandwich costs "only" 26 Euro. ;) Nevertheless, we were deceived by the lounge. NO comparision to the real Executive lo',
#   'time': '2011-04-29',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4f1',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Stunning view at sunset you fall in love also with a rock if you eat here!',
#   'time': '2011-07-27',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4f2',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Fantastic conference room. Fantastic conference.',
#   'time': '2011-09-28',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4f4',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Best swimming pool in Rome!',
#   'time': '2011-10-18',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4f5',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'what a glamorous stay I had over there :)',
#   'time': '2012-04-03',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4f8',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Living the Scentsy Dream!!! Http://www.GetScentsified.com',
#   'time': '2012-04-22',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4f9',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The first time i see internet price for 21€ per day... Shame on the hotel. All over the world hotels have free access or price is just coins.',
#   'time': '2012-04-27',
#   'wordsCount': 27,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4fa',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Internet is 25 euros per day , whatta .....',
#   'time': '2013-02-02',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4fd',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Good service n very nice rooms with good view',
#   'time': '2013-03-18',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e4fe',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': '€25 charge for Internet-24 hour rate!',
#   'time': '2013-04-15',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e500',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Only 2 tv channels in English',
#   'time': '2013-04-15',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e501',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Beautiful and comfortable, a real 5 star however a bit far from the Historic Center.',
#   'time': '2013-04-17',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e502',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Gold member benefits are worth it - free wifi works even at the pool.',
#   'time': '2013-05-18',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e504',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'If you are not hotel guest forget about going to the swimming pool, it costs "only" 45 Euro no matter if you stay all day or only one hour. During weekends special price 85 euro for the day',
#   'time': '2013-07-08',
#   'wordsCount': 36,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e505',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "It's quite far from the city centre, but it's very serene and has a breathtaking view.",
#   'time': '2013-07-24',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e506',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'You have to pay extra to use the pool. They are nuts...',
#   'time': '2013-07-27',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e507',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Internet is expensive and unreliable so it's not really worth it unless you really need it.",
#   'time': '2013-07-28',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e508',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Stunning view from the 9th floor!',
#   'time': '2013-07-31',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e509',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Best Rome "city views" !!',
#   'time': '2013-08-04',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e50a',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Highly recommend. Gorge... City view with all if Rome. Vatican City in view of our balcony!!! Spectacular.',
#   'time': '2013-08-10',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e50b',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great hotel especially if gold hilton member. Free wifi for "hhonorsvip" ;), free breakfast and welcome drink. Thanks for the great service. Breakfast by the pool outside is worth the wait',
#   'time': '2013-09-22',
#   'wordsCount': 30,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e50e',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Hilton Diamond members are treated very well.  Love this hotel.',
#   'time': '2013-09-27',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e50f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The view f(Rom) above is priceless, make sure you book a room with balcony!',
#   'time': '2013-09-28',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e510',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Breath taking view overlooking the city & the Vatican from my balcony at the 6th floor.',
#   'time': '2013-10-20',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322dae9eef5a5062e511',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "This place sucks!  Can't believe they advertise as 4 stars. Concierge is also a complete moron about the neighborhood. Would not recommend.",
#   'time': '2010-10-04',
#   'wordsCount': 21,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5ed',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Not the first time here though that was not my decision. Some parts cool, many others (like most of the rooms!) old, used and just not up to expectations. Overrated!',
#   'time': '2011-01-31',
#   'wordsCount': 30,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5ee',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'First receptionist was not nice at all. The others ok.',
#   'time': '2011-07-18',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5ef',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Breakfast room i so noisy, and coffee sucks!',
#   'time': '2011-07-18',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5f0',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Breakfast room i so noisy, and coffee sucks!',
#   'time': '2011-07-18',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5f1',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 2,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "The stylish photos is a bit manipulative. Ripa probably WAS modern and state-the-art back in 1997. Today it lacks finish and has many weaknesses. No free Wi-Fi. It'll cost extra.",
#   'time': '2012-10-10',
#   'wordsCount': 29,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5f6',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Weirdest place. The Internet options suck. No way of getting a decent connection for more than 1 computer. Is it 2003 or 2013?',
#   'time': '2013-01-27',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5f7',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Good Breakfast',
#   'time': '2013-04-07',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5f8',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The picture on trip advisor and the site are totally misleading run down rooms with smelly pillows and huge 1980 TVs reception sucks breakfast sucks .. Internet sucks .. Would not recommend  to anyone',
#   'time': '2013-06-14',
#   'wordsCount': 31,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5fb',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Big room with a little kitchen and balkony. Free Wifi is fine too. Good brakefast and friendly staff.',
#   'time': '2013-07-30',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5fc',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'WLAN is free but bad connection if any.',
#   'time': '2013-10-07',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5fd',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Super disappointing!!! Photos were misleading. Staffs were rude!',
#   'time': '2013-10-19',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7322fae9eef5a5062e5fe',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Join the free pasta-party!!',
#   'time': '2010-09-13',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73233ae9eef5a5062e73e',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The lift in the building is pretty cool!',
#   'time': '2011-03-06',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73233ae9eef5a5062e73f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Free pizza and wine party is just on monday wendasday and friday also just for 1 hour 7pm and 8pm',
#   'time': '2011-09-08',
#   'wordsCount': 19,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73233ae9eef5a5062e740',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Free wine on arrival if u book more than 3 night! Free wifi. Clean! Friendly staff, I cant complain.. If anything the only negative is breakfast ain't that great but overall this is a great hostel.",
#   'time': '2012-06-22',
#   'wordsCount': 35,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73233ae9eef5a5062e741',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Wifi is totally a mess and it's a very serious hostel. There isn't much fun in here.",
#   'time': '2013-03-29',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73233ae9eef5a5062e743',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Just elivator is cool the others noo.',
#   'time': '2013-04-24',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73233ae9eef5a5062e744',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice hostel! Good kitchen and cleanness.',
#   'time': '2013-05-28',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73233ae9eef5a5062e745',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Wifi login68943127Password64832863',
#   'time': '2013-07-05',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73233ae9eef5a5062e746',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice staff, very friendly!!',
#   'time': '2012-01-20',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73238ae9eef5a5062e95f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'I recommend looking at the coloseum',
#   'time': '2011-12-16',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73239ae9eef5a5062e99f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Ask the reception for the free Wifi user name password',
#   'time': '2012-02-08',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73239ae9eef5a5062e9a0',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Could the bathroom be any smaller?',
#   'time': '2012-02-19',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73239ae9eef5a5062e9a1',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'yep tiny rooms, but not planning to stay in the room all the time!',
#   'time': '2012-04-15',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73239ae9eef5a5062e9a2',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great location above all (near the Colosseum)!... Small rooms, extremely small bathrooms, breakfast so, so...',
#   'time': '2012-07-16',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73239ae9eef5a5062e9a5',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "My single room was small, but that's normal for Rome.  It's fine for 1 person.  It's not too fancy, but it's clean.  The location is great, and my room rate included free wifi and breakfast every day.",
#   'time': '2012-10-02',
#   'wordsCount': 36,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73239ae9eef5a5062e9a6',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Amazing view from the roof top bar and pool!!!',
#   'time': '2013-09-16',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73239ae9eef5a5062e9a7',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 8,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nothing is cheap in Rome except hostels. However, this simple hotel is clean and in close to Termini.',
#   'time': '2010-06-18',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7323dae9eef5a5062eaa9',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Clean, simple, and yes it close from termini ;)',
#   'time': '2010-07-16',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7323dae9eef5a5062eaaa',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'I give it 4.5* for clean, comfort, location, service!',
#   'time': '2011-09-17',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7323dae9eef5a5062eaab',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Wifi code is 0102030405',
#   'time': '2011-12-30',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7323dae9eef5a5062eaac',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very close from Termini train station. Clean. Great people working there. But definity NOT a 4 star hotel, maybe 3.',
#   'time': '2013-09-04',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7323dae9eef5a5062eaad',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "€22 a bed, cash only at check in, post office in the square has the best commission price I've seen so far for currency exchange; paid €2,58 ..I think it's a flat rate.",
#   'time': '2011-09-22',
#   'wordsCount': 31,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7323dae9eef5a5062eac6',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'so nice and quite place for staying in rome',
#   'time': '2012-05-25',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73241ae9eef5a5062ebe1',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The Hotel Felice: a good idea in Rome.Great hotel in Rome center, budget and friendly',
#   'time': '2011-01-08',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec65',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'stay far far away - take my word for it',
#   'time': '2011-08-06',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec67',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great hotel in the centre of Rome',
#   'time': '2011-11-07',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec6a',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "New Year's Eve in Rome",
#   'time': '2011-12-27',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec6b',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Christmas terrace',
#   'time': '2011-12-27',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec6d',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'private bath',
#   'time': '2011-12-27',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec6f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Private bath Hotel Felice',
#   'time': '2011-12-27',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec70',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Hotel Felice location',
#   'time': '2011-12-27',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec71',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Special offers for January 2012 in Rome',
#   'time': '2012-01-03',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec72',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Last second - Last minute Rome hotel Felice',
#   'time': '2012-01-03',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec73',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Special offers for group in Rome',
#   'time': '2012-01-03',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec74',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Perfect location....and Friendly staff.!!!!!!',
#   'time': '2012-01-13',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec7b',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Excellent hotel close to the Termini train station, friendly staff, very clean.',
#   'time': '2012-01-31',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec7c',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The city tax is "free" until you check out. Then they\'ll ask you for it and your entire bill in cash! At least that was my experience.',
#   'time': '2012-02-06',
#   'wordsCount': 27,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73243ae9eef5a5062ec7d',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great place to go. Do not hesitate',
#   'time': '2010-12-27',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73244ae9eef5a5062ecc1',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great hotel! Love it!',
#   'time': '2011-07-03',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73244ae9eef5a5062ecc2',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Very clean and sleek design. Staff are very helpful. Good location. Say 'Yes' to this hotel.",
#   'time': '2011-11-25',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73244ae9eef5a5062ecc5',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great hotel. Staff are very helpful and the accommodations are comfortable.',
#   'time': '2013-01-03',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73244ae9eef5a5062ecc7',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Say "yes" to Hotel Yes.  Great location, near Termini.  Very clean and comfortable modern accommodations.  Wonderful staff!  Don\'t hesitate to book here.',
#   'time': '2013-03-28',
#   'wordsCount': 22,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73244ae9eef5a5062ecc8',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 8,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Rooms are tiny - but, it's an excellent location and has fantastic staff!",
#   'time': '2011-09-02',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73248ae9eef5a5062ee25',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Very nice place to stay.. close to everything, but rooms are bit smaller and during the summer air conditioning doesn't handle a full room..",
#   'time': '2011-09-14',
#   'wordsCount': 24,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73248ae9eef5a5062ee26',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Good location, price and you will meet people from all around the globe!',
#   'time': '2012-01-04',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73248ae9eef5a5062ee27',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great atmosphere, owne is a great individual. Free pasta and cocktail nights are a must :D really good price for all it offers and a good location.',
#   'time': '2012-02-28',
#   'wordsCount': 27,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73248ae9eef5a5062ee29',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "That's an amazing funny party hostel. Miss it a lot as well s Rome.",
#   'time': '2012-02-29',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73248ae9eef5a5062ee2a',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "It's a really good place for a good price. Meet with Salvatore and try his spaghetti!!! I love this place:)",
#   'time': '2012-05-20',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73248ae9eef5a5062ee2b',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Worst hostel I've ever been. Bed bugs and things like that. Never again...",
#   'time': '2013-01-07',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73248ae9eef5a5062ee2c',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Free wifi!',
#   'time': '2011-08-25',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73248ae9eef5a5062ee31',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
# ...
#   'time': '2012-06-29',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c11',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Rooms are quite old but after all it's a nice hotel! Really quite. Nice SPA and open air swimming pool. Food is good and the club sandwich is awesome! Close to st. Peter 10 min taxi.",
#   'time': '2012-07-25',
#   'wordsCount': 35,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c12',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Don't walk from Roma Termini. It will break your feet and the hotel staff will not be sympathetic.",
#   'time': '2012-08-28',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c13',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Quite far away from all the touristy places but modern and large rooms.',
#   'time': '2012-10-25',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c14',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The hotel is okay, but they need to learn A LOT about customer service. The breakfast and lunch buffet are excellent.  Right around the corner is a wonderful restaurant.',
#   'time': '2013-05-04',
#   'wordsCount': 29,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c15',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "This is a great family hotel, especially for those traveling with young children. Rooms are big & they have connecting doors. Also there's a nice size outdoor & indoor pool for days you want to relax.",
#   'time': '2013-08-24',
#   'wordsCount': 34,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c16',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great scrambled eggs for breakfast',
#   'time': '2013-10-29',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c17',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Should come with lots of wide load stickers. Usually departing or arriving via cruise ships',
#   'time': '2013-10-30',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c18',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'what a nice lobby',
#   'time': '2012-07-10',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c1d',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'for some exercise',
#   'time': '2012-07-10',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c1e',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The classic Mediterranean food served here is excellent, and the cafeteria setting is very comfy and wonderful.',
#   'time': '2012-05-01',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c1c',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Wifi is free in the lobby but not in the rooms. There are no Tea/Coffee facilities in the room, as per usual the mini bar is very expensive.',
#   'time': '2012-09-17',
#   'wordsCount': 29,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c1f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice and quit rooms. The breakfast is ok, but not very special (today we had some old bread). Wifi is not free. Location is very good in the center....',
#   'time': '2013-05-12',
#   'wordsCount': 29,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c21',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 2,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'A great hotel to stay in rome if u want to be in between the Vatican City and down town Rome. Rooms r clean and excellent service but one negative aspect is that there is no free wifi in the rooms',
#   'time': '2013-08-13',
#   'wordsCount': 41,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c22',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Wonderful hotel! They brought up a complimentary bottle of champagne when they heard we were on our honeymoon. Beautiful rooftop terrace, and very friendly staff. Very clean. I would stay here again!',
#   'time': '2013-09-30',
#   'wordsCount': 32,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c23',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "great classic hotel in elegant part of town. while not in the historic centre it's within striking distance and has great buffet breakfast on very elegant roof terrace.free wifi too. recommended",
#   'time': '2010-04-18',
#   'wordsCount': 32,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c26',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great Roman hotel. BEST breakfast on sun filled garden terrace and free wifi..all inclusive in price too. elegant part of town. fantastic value, loads of character & highly recommended!',
#   'time': '2010-04-23',
#   'wordsCount': 29,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bcae9eef5a50629c27',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 2,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Beautiful and good Hotel! Expensive!!! In a beautiful place in Rome. There's a metro station near (Barberini) and it's near the Piazza di Republica! The Gyn is so small and not good!",
#   'time': '2011-07-18',
#   'wordsCount': 32,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c2c',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "One of Rome's great hotels - cannot beat the location. Bernardo, the concierge, is a genius. Don't miss the view from the rooftop restaurant - bring your camera!",
#   'time': '2012-07-22',
#   'wordsCount': 28,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c2e',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The rooftop terrace here offers unique views of the Eternal City.',
#   'time': '2012-10-19',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c2f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Ask for a room with a Balcony or at least a via veneto view!',
#   'time': '2013-06-09',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c32',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Comfortable, clean rooms; nice service and healthy breakfast buffet.',
#   'time': '2013-10-01',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c3d',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Bad toilets :\\ the breakfast room is small, could only fit about 60 guests maximum.',
#   'time': '2011-08-11',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c3f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Don't be loud. They have no tolerance for noise",
#   'time': '2012-01-11',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c41',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very clean bedroom and a really nice and updated bathroom. Great value-for-money hotel in an excellent location.',
#   'time': '2011-09-01',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c47',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Vegetarian and coeliac menus are available at the restaurant in this hotel.',
#   'time': '2012-05-03',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c49',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Ask for a room not on the street side. It's very loud at night.",
#   'time': '2012-07-04',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c4a',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Breakfast is 6:30 to 10:30. You can get free ice cube from the bar and bring back to your room.',
#   'time': '2013-10-03',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c50',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Luxury Must had the opportunity to interview the GM of the amazing Regina Hotel Baglioni in Roma',
#   'time': '2010-11-02',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c52',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'One of my favorite hotels in the world. Try the delectable breakfast buffet.',
#   'time': '2011-01-02',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c53',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very nice hotel and wonderful staff. Really a very pleasant stay.',
#   'time': '2012-11-30',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c56',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'I simply love this hotel in the heart of Via Veneto. Interiors are elegant but at the same time very cosy. Also staff was very kind and cordial. Looking forward to return.',
#   'time': '2013-04-04',
#   'wordsCount': 32,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c58',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Just enjoy the great view from the roman penthouse Suite of the regina baglioni. Amazing. That's is the vatican",
#   'time': '2013-06-02',
#   'wordsCount': 19,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c59',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'My living in the dolce vita suite',
#   'time': '2013-06-02',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c5a',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'My bedroom in dolce vita in the',
#   'time': '2013-06-02',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c5b',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Baglioni Hotels offers you a special discount if you book with "Baglioni Saver". Enjoy a special discount of up to 25% on our Daily Rate View Conditions --> http://bit.ly/15sxPgA',
#   'time': '2013-09-02',
#   'wordsCount': 31,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c5c',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The "Dolce Vita" is reborn. Thanks to Regina Hotel Baglioni in Rome is easy to live all the excitement of a exclusive holiday http://www.baglionihotels.com/Rome',
#   'time': '2013-09-11',
#   'wordsCount': 28,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c5d',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': '12 Oct - 2 Feb Rome’s Chiostro del Bramante will be hosting a major exhibition focusing on the figure of Cleopatra. Book at Regina Hotel and discover the fascinating life of the last queen of Egypt.',
#   'time': '2013-09-17',
#   'wordsCount': 35,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c5e',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Five star decor but three star service',
#   'time': '2013-10-02',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c5f',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Celebrate the arrival of the new year in the Eternal City and make a toast to 2014 at the Regina Hotel Baglioni in Rome. Discover the special package just for you --> http://goo.gl/3XxK2O',
#   'time': '2013-10-14',
#   'wordsCount': 36,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c60',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Do you want to discover how to enjoy a special discount of 20% on your roman vacation at the Regina Hotel Baglioni? Find out now --> http://goo.gl/oNcQvi',
#   'time': '2013-10-16',
#   'wordsCount': 29,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c61',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 8,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "There's a reason this place is cheap and not a good one, make sure you get an upper floor room and ignore fitness room and food. Thar said, it's clean and tidy which is better than most rome hotels.",
#   'time': '2010-10-20',
#   'wordsCount': 39,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c64',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Seems nice. Too bad they're doing construction.",
#   'time': '2011-03-25',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c65',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'I really like this hotel:) the free wifi is awesome.',
#   'time': '2012-07-12',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c67',
#   'location': 'Rome'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Don't forget to ask for a Wi-Fi access code if you have a laptop with you, (free of charge)",
#   'time': '2011-02-21',
#   'wordsCount': 19,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a731bdae9eef5a50629c72',
#   'location': 'Rome'},
#  ...]

# %%
import time
locations = ['Rome', 'Amsterdam','Paris','Tuscany']
#location_data = [data]
rome_amsterdam = []
for i in locations:
    response = requests.get("http://tour-pedia.org/api/getReviews?location=" + i + "&language=en")
    buffer = response.json()
    for x in range(len(buffer)):
        buffer[x]['location'] = i
    paris_tuscany.append(buffer)
    print("Sleeping")
    if i != 'Tuscany':
        time.sleep(30)
    print("ah")
# Out:
# Sleeping
# ah
# Sleeping
# ah

# %%
paris_tuscany[2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 paris_tuscany[2]
#
# NameError: name 'paris_tuscany' is not defined

# %%
location_data = paris_tuscany[0] + paris_tuscany[1]

# %%
len(location_data)
# Out:
# 194013

# %%
location_data = location_data + paris_tuscany[2] + paris_tuscany[3]

# %%
import json

# Open and read the JSON file
locations = ['barcelona','berlin','dubai','london']

for i in locations:
    with open(i + '.json', 'r') as file:
        data = json.load(file)
        for i in data:
            i['location'] = i
            location_data.append(i)

# %%
df = pd.DataFrame(location_data)

# %%
df
# Out:
#        language  polarity rating        source  \
# 0            en         0      0    Foursquare
# 1            en         5      0    Foursquare
# 2            en         5      0    Foursquare
# 3            en        10      0    Foursquare
# 4            en         9      0    Foursquare
# ...         ...       ...    ...           ...
# 194008       en        10      5  GooglePlaces
# 194009       en        10      5  GooglePlaces
# 194010       en        10      4  GooglePlaces
# 194011       en        10      4  GooglePlaces
# 194012       en        10      2  GooglePlaces
#
#                                                      text        time  \
# 0       When u got out of the hotel turn left and then...  2012-02-20
# 1       Get a courtyard room ... Very loud off the str...  2013-03-14
# 2       Very good location, close to the subway. Frien...  2013-08-11
# 3       Designs of the rooms are so nice and it is als...  2013-10-16
# 4       Modern hotel in Paris. Small, but well designe...  2011-10-09
# ...                                                   ...         ...
# 194008  I arrived at Amsterdam at 10pm, and decided to...  2013-08-08
# 194009  Great place to drink a coffe before take the b...  2012-05-27
# 194010  Very tasty dishes. Fast and simple. Good take ...  2013-04-10
# 194011  Good Turkish food, fresh Maza and unlimited am...  2011-09-25
# 194012  Quite pricey and the food is OK, but doesn&#39...  2012-12-07
#
#         wordsCount                                            details  \
# 0               26  http://tour-pedia.org/api/getReviewDetails?id=...
# 1                9  http://tour-pedia.org/api/getReviewDetails?id=...
# 2               20  http://tour-pedia.org/api/getReviewDetails?id=...
# 3               22  http://tour-pedia.org/api/getReviewDetails?id=...
# 4               13  http://tour-pedia.org/api/getReviewDetails?id=...
# ...            ...                                                ...
# 194008         126  http://tour-pedia.org/api/getReviewDetails?id=...
# 194009          18  http://tour-pedia.org/api/getReviewDetails?id=...
# 194010          24  http://tour-pedia.org/api/getReviewDetails?id=...
# 194011          48  http://tour-pedia.org/api/getReviewDetails?id=...
# 194012          13  http://tour-pedia.org/api/getReviewDetails?id=...
#
#          location
# 0           Paris
# 1           Paris
# 2           Paris
# 3           Paris
# 4           Paris
# ...           ...
# 194008  Amsterdam
# 194009  Amsterdam
# 194010  Amsterdam
# 194011  Amsterdam
# 194012  Amsterdam
#
# [194013 rows x 9 columns]

# %%
df['location'].value_counts()

# %%
df.to_csv('full.csv')

# %%
import numpy as np

meanWords = np.mean(df['wordsCount'])
devWords = np.std(df['wordsCount'])

# %%
meanWords + devWords
# Out:
# 62.81300819190531

# %%
meanWords
# Out:
# 25.150854269389217

# %%
devWords
# Out:
# 37.6621539225161

# %%
df['polarity'].value_counts()
# Out:
# polarity
# 10    164177
# 5     112667
# 0      33525
# 9      17708
# 8      17444
# 2       8418
# 1       3618
# Name: count, dtype: int64

# %%
df = pd.read_csv('Data\\amsterdam-accommodation.csv')

# %%
df.dropna(subset=['reviews'], inplace=True)

# %%
df
# Out:
#                       address       category     id              lat  \
# 0                         NaN  accommodation  31052        52.356347
# 1    De Tuin van AJ & Kristel  accommodation  31056  52.355473708753
# 2                         NaN  accommodation  31167        52.382517
# 3                         NaN  accommodation  31176  52.350272159742
# 4         Lambertus Zijlpelin  accommodation  31248      52.38013065
# ..                        ...            ...    ...              ...
# 113           Zuiderzeeweg 46  accommodation  33186        52.371866
# 114                       NaN  accommodation  33242  52.376194000244
# 115                       NaN  accommodation  33259  52.355841498675
# 116                       NaN  accommodation  33310  52.375370025635
# 117                       NaN  accommodation  33347        52.403696
#
#                  lng   location                         name  \
# 0           4.997105  Amsterdam                          Kos
# 1    4.9932861328125  Amsterdam                   Hawaijburg
# 2           4.791104  Amsterdam  Perfect House In Amsterdam!
# 3    4.7806079636587  Amsterdam                  Huize Verel
# 4         4.80258218  Amsterdam       d' R.C : Dream Academy
# ..               ...        ...                          ...
# 113         4.961772  Amsterdam                  P&R Zeeburg
# 114  4.9379887580872  Amsterdam              Capitan's House
# 115  4.9469025006495  Amsterdam                Karls Boomhut
# 116  4.9460759162903  Amsterdam          B&B patio amsterdam
# 117         4.997721  Amsterdam                Het Zomerhuis
#
#                    originalId polarity      subCategory  \
# 0    4e64ba6818a8ce02fdd4b1ce        0            Hotel
# 1    4c6669119cb82d7fbe8b90d2        0           Resort
# 2    527011a3498e754b851a3efd        0  Bed & Breakfast
# 3    4e39479eae60f589a5d91d35        0           Resort
# 4    4d87dc29d85f3704d1f8c5db        0           Resort
# ..                        ...      ...              ...
# 113  4b30f6f9f964a5206bfd24e3        0          Parking
# 114  4e3b14cd62e19d61094f0c62        0  Bed & Breakfast
# 115  4e67df2d18a8bf0571cae14b        0           Resort
# 116  4e3abebfd22d4aca87922c95        0  Bed & Breakfast
# 117  4de8fa4fd1648c97963ff230        0            Hotel
#
#                                                details  \
# 0    http://tour-pedia.org/api/getPlaceDetails?id=3...
# 1    http://tour-pedia.org/api/getPlaceDetails?id=3...
# 2    http://tour-pedia.org/api/getPlaceDetails?id=3...
# 3    http://tour-pedia.org/api/getPlaceDetails?id=3...
# 4    http://tour-pedia.org/api/getPlaceDetails?id=3...
# ..                                                 ...
# 113  http://tour-pedia.org/api/getPlaceDetails?id=3...
# 114  http://tour-pedia.org/api/getPlaceDetails?id=3...
# 115  http://tour-pedia.org/api/getPlaceDetails?id=3...
# 116  http://tour-pedia.org/api/getPlaceDetails?id=3...
# 117  http://tour-pedia.org/api/getPlaceDetails?id=3...
#
#                                                reviews
# 0    http://tour-pedia.org/api/getReviewsByPlaceId?...
# 1    http://tour-pedia.org/api/getReviewsByPlaceId?...
# 2    http://tour-pedia.org/api/getReviewsByPlaceId?...
# 3    http://tour-pedia.org/api/getReviewsByPlaceId?...
# 4    http://tour-pedia.org/api/getReviewsByPlaceId?...
# ..                                                 ...
# 113  http://tour-pedia.org/api/getReviewsByPlaceId?...
# 114  http://tour-pedia.org/api/getReviewsByPlaceId?...
# 115  http://tour-pedia.org/api/getReviewsByPlaceId?...
# 116  http://tour-pedia.org/api/getReviewsByPlaceId?...
# 117  http://tour-pedia.org/api/getReviewsByPlaceId?...
#
# [117 rows x 12 columns]

# %%
reviews_amsterdam = []

for i in range(len(df['reviews'])):
    buffer = requests.get(df['reviews'].iloc[i]).json()
    location = df['location'].iloc[i]
    category = df['category'].iloc[i]
    #subcat = df['subCategory'].iloc[i]
    lat = df['lat'].iloc[i]
    lng = df['lng'].iloc[i]
    for x in buffer:
        if x['language'] == 'en':
            x['location'] = location
            x['category'] = category
            x['subcat'] = subcat
            x['lat'] = lat
            x['lng'] = lng
            reviews_amsterdam.append(x)
    if i % 100 == 0:
        print(i)
# Out:
# 0
# 100

# %%
reviews_amsterdam
# Out:
# [{'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'In for a swim? Let me know!',
#   'time': '2010-08-14',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73980ae9eef5a506411ee',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.355473708753',
#   'lng': '4.9932861328125'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Try the food, booze and men. Fabulous for ice skating.',
#   'time': '2012-02-01',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73986ae9eef5a506412a5',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.350272159742',
#   'lng': '4.7806079636587'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Good Dreamz',
#   'time': '2011-04-21',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7398aae9eef5a506412f9',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.38013065',
#   'lng': '4.80258218'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'reading my dream',
#   'time': '2011-03-24',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a7398aae9eef5a506412fa',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.38013065',
#   'lng': '4.80258218'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': '...take the tram n.2 and go in 15 mins to the centre ;)',
#   'time': '2013-03-01',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641641',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'free wifi in the rooms : yes wifi in every room: no its too far to some rooms',
#   'time': '2012-12-27',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641642',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Clean, confortable and wifi free.',
#   'time': '2012-11-07',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641643',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "The hotel is Ok. Nice snack bar open 24/7. Wifi is free and usually Ok. The neighborhood isn't the nicest and is is not idealy located.",
#   'time': '2012-09-11',
#   'wordsCount': 25,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641644',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The lounge area here is a great place to hang out during lazy days. You can watch TV there or play billiards.',
#   'time': '2012-09-03',
#   'wordsCount': 22,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641645',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "The WiFi's free and the rooms are ok. The cafe works 24/7: try homemade tiramisu.",
#   'time': '2012-07-08',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641646',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Wi-Fi is completely free (might not have been in the past when the other tips were left); there's no password and then you're presented with a login page where you just have to accept the T&C, simple!",
#   'time': '2012-06-30',
#   'wordsCount': 38,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641647',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Free wifi in the rooms. And you get BBC 1 and 2',
#   'time': '2012-02-24',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641648',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'No need to set the timer. Housekeeping will wake you up :p',
#   'time': '2011-06-26',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a50641649',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Checkin for free wifi',
#   'time': '2011-03-08',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a5064164a',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Try the dayspecial: Chef Walter is grilling the tuna to perfection!',
#   'time': '2011-03-03',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a5064164b',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Free Wifi for you as foursquare user. Check in @ Hem Hotel Amsterdam and get 24 hours of free Wifi with your stay.',
#   'time': '2011-01-07',
#   'wordsCount': 21,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a5064164c',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "You can use HEM Hotel's Facebook promotion and get 24 hours of free Wifi.",
#   'time': '2010-05-17',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a5064164d',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'There is no free wi-fi over here... Charging 10€/hour is very disappointing',
#   'time': '2010-05-13',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a3ae9eef5a5064164e',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.348997187115',
#   'lng': '4.8426260401684'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'very central. warm rooms but no wifi',
#   'time': '2013-03-26',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a4ae9eef5a5064167b',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.38874',
#   'lng': '4.83822'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Check out the amazing swimming-pool and cocktail bar, but most of all the giant roof golf field !',
#   'time': '2011-04-02',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a5ae9eef5a506416a7',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.38067970461',
#   'lng': '4.8481880793985'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'İt is called center but it is not ! Ordinary hotel...',
#   'time': '2013-07-01',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739a6ae9eef5a506416cc',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.357660143524',
#   'lng': '4.8447188115051'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Simple but decent b&b - rent bikes for your whole stay to get around town',
#   'time': '2011-09-17',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739abae9eef5a50641749',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.354501987387',
#   'lng': '4.8531306294395'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "TOPservice!! Klaar terwijl u wacht! En dat om half 8 's avonds. My hero of the day!",
#   'time': '2013-08-08',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739acae9eef5a5064175e',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.346930497088',
#   'lng': '4.8522721926536'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'so rockin with the cheesecake and all',
#   'time': '2013-11-08',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739acae9eef5a50641773',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.333686995487',
#   'lng': '4.8554688692093'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Lunch time!',
#   'time': '2013-11-06',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739acae9eef5a50641774',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.333686995487',
#   'lng': '4.8554688692093'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Love the view from my office...',
#   'time': '2013-08-21',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739acae9eef5a50641775',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.333686995487',
#   'lng': '4.8554688692093'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The new office is great!',
#   'time': '2013-07-12',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739acae9eef5a50641776',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.333686995487',
#   'lng': '4.8554688692093'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'You should try their toasties! ;)',
#   'time': '2012-12-20',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739acae9eef5a50641777',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.333686995487',
#   'lng': '4.8554688692093'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Olery is part of Mapped in World digital map. Join the community',
#   'time': '2012-10-09',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739acae9eef5a50641778',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.333686995487',
#   'lng': '4.8554688692093'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Very good B&B. Friendly people, wonderful accomodation and nearby Amsterdamse bos. On the bike you're in à few minutes in the city centre!!",
#   'time': '2013-07-21',
#   'wordsCount': 23,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739adae9eef5a5064177f',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.332564',
#   'lng': '4.852985'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Enjoy Mediterranean-oriented dishes while admiring views of the river at the Brasserie Flavours.',
#   'time': '2012-06-20',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739b2ae9eef5a5064181f',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.392751960469',
#   'lng': '4.8685943205015'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Go stand on the balcony and sing your favorite song out loud!',
#   'time': '2010-02-18',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739b4ae9eef5a50641840',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.383406530735',
#   'lng': '4.8775670072421'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Roof on 10th floor. Nice 360 degree city view.',
#   'time': '2013-09-15',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739b6ae9eef5a506418cb',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.351549932622',
#   'lng': '4.8721034073664'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Htel guests only.. you'll find it on the 15th floor...",
#   'time': '2011-07-03',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739b7ae9eef5a50641955',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.32741',
#   'lng': '4.871802'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Relax with a cup of Nespresso coffee while enjoying the spectacular view over the city.',
#   'time': '2011-07-03',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739b7ae9eef5a50641956',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.32741',
#   'lng': '4.871802'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Relax with a cup of Nespresso coffee while enjoying the spectacular view over the city.',
#   'time': '2011-07-03',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739b7ae9eef5a50641957',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.32741',
#   'lng': '4.871802'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The nicest place to sleep in Amsterdam City Centre. Makes you never wanna leave! Book it now!',
#   'time': '2013-05-10',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739bbae9eef5a506419a7',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.382644',
#   'lng': '4.883256'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Find your favorite taste of Nespresso in the kitchen.',
#   'time': '2011-07-04',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c0ae9eef5a50641c24',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.327414451971',
#   'lng': '4.8720963562198'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Four levels of pure pleasure like a real amsterdamian!',
#   'time': '2012-04-05',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c3ae9eef5a50641c78',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.400417686093',
#   'lng': '4.8892417350497'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Hummus sandwich at the end and the sausage man at number 187.',
#   'time': '2013-01-05',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641c93',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.380173347042',
#   'lng': '4.884068103015'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'You can find the best cheeses in town on Saturday!',
#   'time': '2012-03-31',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641c94',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.380173347042',
#   'lng': '4.884068103015'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Try the cheese stand with the two grumpy old men around hoyse number 50. They're the most sympathetic and their cheese a steal!",
#   'time': '2011-08-20',
#   'wordsCount': 22,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641c95',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.380173347042',
#   'lng': '4.884068103015'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Just a very nice entourage: especially when the sun is shining and you are with your friends drinking some wines/beers',
#   'time': '2010-05-21',
#   'wordsCount': 21,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641c96',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.380173347042',
#   'lng': '4.884068103015'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Very nice hotel with friendly and always helpful staff. Location is excellent - 10 minutes walk from Central Station and quiet rooms facing one of the Amsterdam's channels. Free wifi. Nice jazz bar.",
#   'time': '2013-11-04',
#   'wordsCount': 32,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641caf',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379113',
#   'lng': '4.889878'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "The staff are amazing. I 'lost' my camera and they directed us to the police station. They asked how we got on when we got back. Great service here!",
#   'time': '2012-11-25',
#   'wordsCount': 29,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641cb1',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379113',
#   'lng': '4.889878'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very nice hotel with friendly staff. Coffee and tea selection in the room was very nice. Great location.',
#   'time': '2012-11-22',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641cb2',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379113',
#   'lng': '4.889878'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very good hotel, honest price and a very comfortable bed. Coffee machine in the bedroom, iPod aplifier with alarm clock, cable tv, etc',
#   'time': '2012-02-17',
#   'wordsCount': 23,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641cb3',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379113',
#   'lng': '4.889878'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very nice hotel in a very good area',
#   'time': '2011-12-18',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641cb4',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379113',
#   'lng': '4.889878'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Room 337 is a penthouse with good views.',
#   'time': '2011-11-14',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641cb5',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379113',
#   'lng': '4.889878'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very nice hotel. Also in a good position. Recomended',
#   'time': '2011-03-17',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641cb8',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379113',
#   'lng': '4.889878'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'This is the best hotel in Amsterdam!',
#   'time': '2011-02-22',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c4ae9eef5a50641cb9',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379113',
#   'lng': '4.889878'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Good location. That's all... It's way too expensive for what it is.",
#   'time': '2013-10-01',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d3b',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Room clean, wifi Internet connection slow, perfect location',
#   'time': '2013-02-04',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d3c',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'This hotel is more traveller and less business orientated. I do not recommend it',
#   'time': '2013-01-30',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d3d',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The Dam Square is just five minutes walk from here.',
#   'time': '2012-07-19',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d3e',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Some of the attractions that you can easily visit from here are the Anne Frank House, the Van Gogh Museum, and the Rijksmuseum.',
#   'time': '2012-05-01',
#   'wordsCount': 23,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d3f',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "I will not stay here anymore. It's the most boring hotel in Amsterdam.",
#   'time': '2012-03-22',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d40',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'nice location and good price',
#   'time': '2012-03-15',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d41',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice hotel. Spacious rooms and friendly staff.. Totally worth the money!',
#   'time': '2012-02-26',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d42',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice and clean place. Great value for money!',
#   'time': '2012-02-25',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d43',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice and clean otel.',
#   'time': '2012-02-11',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d44',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Rooms are OK, but some stuff (esp laundry) is WAY overpriced and DO NOT get a room on the ground floor... It may well open onto the courtyard.',
#   'time': '2011-09-27',
#   'wordsCount': 28,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d45',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Btw: Don't book here. Dirty rooms, incompetent staff, overprized!",
#   'time': '2011-09-16',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d46',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'very little rooms, but helpful and kind staff',
#   'time': '2011-09-12',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d47',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Incomparable central location! This is a top ranked hotel in Amsterdam where budget accommodation means great location, service and cleanliness. Check out what our customers say about it!',
#   'time': '2011-09-08',
#   'wordsCount': 28,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d48',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Don't bother coming here. It's a proper mong hotel.",
#   'time': '2010-02-28',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d49',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.371856352052',
#   'lng': '4.8874758754551'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'This urban extension was the largest and most homogeneous of its time. It was a model of large-scale town planning, and served as a reference throughout the world until the 19th century.',
#   'time': '2012-08-09',
#   'wordsCount': 32,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c5ae9eef5a50641d52',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.365773433416',
#   'lng': '4.889988899231'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "For everybody who get's picked up under station RAI",
#   'time': '2011-07-27',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c7ae9eef5a50641e28',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.337117761112',
#   'lng': '4.890564958546'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice view ; stylish and brand new..',
#   'time': '2013-09-12',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739c9ae9eef5a50641e52',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.384702671903',
#   'lng': '4.8940172609692'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The staffs are friendly and nice ..',
#   'time': '2013-10-08',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f2a',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Location is perfect!',
#   'time': '2013-09-22',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f2b',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Everything is old, and a bit noisy. but clean and and the staff are friendly.  Location is very good.  Close to everything.',
#   'time': '2013-09-15',
#   'wordsCount': 22,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f2c',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 8,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "It's a great spot to stay, at the heart of Amsterdam, in a 2 min walking distance to all desired traditional Amsterdam locations... Hotel is tiny but clean. Don't expect so much from breakfast...",
#   'time': '2013-04-26',
#   'wordsCount': 33,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f2d',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The most complicated hotel in the world',
#   'time': '2012-11-04',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f2e',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Dirty,cold and old rooms with rude staff..doesnt worth the money except good location..a big disappointment..',
#   'time': '2012-10-28',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f2f',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nothing special, but a nice, basic hotel. Wi-Fi is useless in the mornings, when there are many people using it.',
#   'time': '2012-10-14',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f30',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Internet connection - Poor. On/Off',
#   'time': '2012-03-07',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f31',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Internet only works during the day.',
#   'time': '2011-07-24',
#   'wordsCount': 6,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f32',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.372093',
#   'lng': '4.894073'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'BARBARA WRÓTNA I LOVE LANVIN I LOVE FASHION I AM A MODEL MY TEL +48895345885',
#   'time': '2013-08-15',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f3b',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.37373022916',
#   'lng': '4.8936102821089'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great little hotel at the heart of Amsterdam. The rooms are kind of small, but equipped well with basic necessities. Internet was free and worked well..',
#   'time': '2013-06-02',
#   'wordsCount': 26,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f3c',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.37373022916',
#   'lng': '4.8936102821089'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'KEEP THE CITY CLEAN IF YOUR VISITING !',
#   'time': '2012-01-16',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f3d',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.37373022916',
#   'lng': '4.8936102821089'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Hotel with an amazingly central location. Maybe decor is a bit dated, but staff is nice, and you're right in the middle of everything.",
#   'time': '2010-08-11',
#   'wordsCount': 24,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739caae9eef5a50641f3e',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.37373022916',
#   'lng': '4.8936102821089'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'This is not a hotel for business also bad cleaning and left with half used soap!!',
#   'time': '2013-09-29',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a5064202d',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very small rooms like cabins. Placed in center of red light district near coffeshops, bars, cafes and girls. In summer daytime on the street you will be in rush with a lot of people',
#   'time': '2013-07-07',
#   'wordsCount': 34,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a5064202e',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Avoid all rooms! Never paid so much for such a bad hotel... :(',
#   'time': '2013-06-14',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a5064202f',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very designed small room , but in the heart of Amsterdam!!!! Don t take the rooms in the top floor (4th).',
#   'time': '2013-03-17',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a50642030',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Hotel is nice and clean but it is situated in the district with sexshops and coffee shops...',
#   'time': '2012-05-07',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a50642031',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Avoid rooms like 403 by the stairs as there are people stomping up and down them all night.',
#   'time': '2012-04-21',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a50642032',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Small rooms but very well located. Don't provide breakfast nor other meals, only vending machines. Nonetheleas there are a lot of good restaurants in the street.",
#   'time': '2012-02-01',
#   'wordsCount': 26,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a50642033',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'They say that you have to buy a ticket for WiFi, but it works for me for free. Excellent! :-)',
#   'time': '2011-11-01',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a50642034',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 9,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Not that good of a hotel. Ask for a room with canal view. And avoid 4th floor. All in all nlt a good place to stay at but location is good',
#   'time': '2011-09-13',
#   'wordsCount': 31,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a50642035',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Really small rooms',
#   'time': '2011-05-17',
#   'wordsCount': 3,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cbae9eef5a50642036',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375654',
#   'lng': '4.898343'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'It does not matter how slowly you go so long as you do not stop. -Confucius',
#   'time': '2013-06-16',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739cdae9eef5a506420ed',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.335075836997',
#   'lng': '4.8896661818542'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Put a recognisable mark on your bike saddle, otherwise you'll have a lot of trouble finding it back",
#   'time': '2011-10-10',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d0ae9eef5a5064232e',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379031121168',
#   'lng': '4.8976707458496'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'More luck to park in the racks next to the station past Regardz.',
#   'time': '2011-06-15',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d0ae9eef5a5064232f',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379031121168',
#   'lng': '4.8976707458496'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'You can try to park your bike here! ;)',
#   'time': '2011-03-31',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d0ae9eef5a50642330',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.379031121168',
#   'lng': '4.8976707458496'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Perfect accommodation! The best one in Amsterdam 😍',
#   'time': '2013-10-16',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d1ae9eef5a506423f6',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.360269',
#   'lng': '4.894731'},
#  {'language': 'en',
#   'polarity': 1,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Staff is friendly and very helpful if you need something just ask them:) Only bad thing about this hotel is rooms and restrooms are extremely small, just like staying in hobbit house. Bring small bags',
#   'time': '2013-08-12',
#   'wordsCount': 35,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d2ae9eef5a5064240d',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.35249',
#   'lng': '4.89366849'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "The cheap bike rentals inside the hotel come with locks and lights -- and there's no reason not to get around Amsterdam on a yellow cruiser.",
#   'time': '2011-08-22',
#   'wordsCount': 26,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d2ae9eef5a5064240e',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.35249',
#   'lng': '4.89366849'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "It's the best BB  ever :-) :-) :-)",
#   'time': '2013-09-21',
#   'wordsCount': 8,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d2ae9eef5a50642417',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.35495',
#   'lng': '4.891453'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Long exposure images while sitting in a Cafe right next to the canal. What else do I need?',
#   'time': '2011-06-23',
#   'wordsCount': 18,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424bf',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.375490097438',
#   'lng': '4.9038440170636'},
#  {'language': 'en',
#   'polarity': 2,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Not recommended for people with heavy luggage. This hotel doesn't have an elevator so beware. For my opinion this hotel is too efficient that it sacrifice comfortability.",
#   'time': '2013-04-16',
#   'wordsCount': 27,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424cd',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.364518533449',
#   'lng': '4.9035047092597'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "The twin room in the 5th floor is a little bit too small for a twin. The carpets are a little bit smelly, but everything's fine. One more downside is they don't have elevator, so beware.",
#   'time': '2013-04-14',
#   'wordsCount': 36,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424ce',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.364518533449',
#   'lng': '4.9035047092597'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Clean but too efficient and loveless. Ok, but not cool.',
#   'time': '2013-03-22',
#   'wordsCount': 10,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424cf',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.364518533449',
#   'lng': '4.9035047092597'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Great hotel in Amsterdam city centar. Clean and beautifull. Family room at first floor is the best.',
#   'time': '2013-02-26',
#   'wordsCount': 17,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424d0',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.364518533449',
#   'lng': '4.9035047092597'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "I want to see in the morning what's like around but nite life is very lively",
#   'time': '2012-11-17',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424d1',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.364518533449',
#   'lng': '4.9035047092597'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Nice view but cold outside',
#   'time': '2012-11-16',
#   'wordsCount': 5,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424d2',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.364518533449',
#   'lng': '4.9035047092597'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Quite window view ) Don't forget to rent a bike at Waterlooplein Flea Market",
#   'time': '2012-03-28',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424d3',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.364518533449',
#   'lng': '4.9035047092597'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Good quality,nice people.i recommend it',
#   'time': '2012-02-10',
#   'wordsCount': 7,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d5ae9eef5a506424d4',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.364518533449',
#   'lng': '4.9035047092597'},
#  {'language': 'en',
#   'polarity': 8,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Cant say nothing bad. Very great staff which can solve any problem,great location in quiet part of the city. Just be carefoul, rooms are tiny! Make sure u get the bigger room upstairs!',
#   'time': '2013-08-03',
#   'wordsCount': 34,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d6ae9eef5a50642509',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.3489619',
#   'lng': '4.908716'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Wifi access code is wifi26rooms for all three wifi networks (Hotel V1, V2, V3)',
#   'time': '2012-01-24',
#   'wordsCount': 15,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d7ae9eef5a50642528',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.346786975237',
#   'lng': '4.9027711942505'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "Ask for Johnny's coffee!",
#   'time': '2011-08-17',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d7ae9eef5a50642529',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.346786975237',
#   'lng': '4.9027711942505'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Room 101 has the size of a stamp, but does have a nice balcony.',
#   'time': '2011-04-08',
#   'wordsCount': 13,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739d7ae9eef5a5064252a',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.346786975237',
#   'lng': '4.9027711942505'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Very basic but clean. And a really nice and cosy atmosphere!',
#   'time': '2013-07-03',
#   'wordsCount': 11,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739dbae9eef5a506425d0',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.36680125',
#   'lng': '4.90920191'},
#  {'language': 'en',
#   'polarity': 0,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "These upstairs like damn ones! Second floor, it's hell if you take your case with you",
#   'time': '2013-04-17',
#   'wordsCount': 16,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739dbae9eef5a506425d1',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.36680125',
#   'lng': '4.90920191'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Do not take the top level. The stairs are hell way too steep, especially if you have 101 luggage to carry!!',
#   'time': '2012-05-06',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739dbae9eef5a506425d2',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.36680125',
#   'lng': '4.90920191'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Top resort',
#   'time': '2011-10-27',
#   'wordsCount': 2,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739e2ae9eef5a506426f7',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.367723',
#   'lng': '4.929416'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Fabulously idyllic.  Beautiful view.  Cozy space.  Stock up on groceries and cook at "home".',
#   'time': '2013-09-21',
#   'wordsCount': 14,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739e3ae9eef5a50642720',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.365662944993',
#   'lng': '4.9089805522979'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'This houseboat is The perfect place for a city trip to Amsterdam.',
#   'time': '2011-09-20',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739e3ae9eef5a50642721',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.365662944993',
#   'lng': '4.9089805522979'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Amazing bed, gorgeous tub (fits two) and perfect living space to just sit and write and stare outside the window.',
#   'time': '2013-07-13',
#   'wordsCount': 20,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739e6ae9eef5a50642777',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.391564621643',
#   'lng': '4.935028553009'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Check out this B&B with Auping Quality Beds!',
#   'time': '2012-09-15',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739e6ae9eef5a50642778',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.391564621643',
#   'lng': '4.935028553009'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'You wanna stay on a typical houseboat? Then this is your place',
#   'time': '2013-10-13',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739e7ae9eef5a50642780',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.376318',
#   'lng': '4.915308'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Dont ask for chips on friday. Thats not allowed.',
#   'time': '2010-09-23',
#   'wordsCount': 9,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739f1ae9eef5a50642891',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.3699121266',
#   'lng': '4.9539035970131'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'Ask for the special coffee brew and use the Nespresso coffee machine.',
#   'time': '2010-01-15',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739f1ae9eef5a50642892',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.3699121266',
#   'lng': '4.9539035970131'},
#  {'language': 'en',
#   'polarity': 5,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': 'The water is gone.',
#   'time': '2012-01-14',
#   'wordsCount': 4,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739f3ae9eef5a506428cd',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.347426197533',
#   'lng': '4.9399852752686'},
#  {'language': 'en',
#   'polarity': 10,
#   'rating': 0,
#   'source': 'Foursquare',
#   'text': "It's a must-visit when in Amsterdam! Cozy house in a wonderful place!",
#   'time': '2013-09-23',
#   'wordsCount': 12,
#   'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a739f6ae9eef5a50642913',
#   'location': 'Amsterdam',
#   'category': 'accommodation',
#   'subcat': 'Home (private)',
#   'lat': '52.383393',
#   'lng': '4.961722'}]

# %%
import os
all_reviews = []
for file in os.listdir('Data'):
    if file == 'barcelona-accommodation.csv':
        break
    df = pd.read_csv('Data\\' + file)
    df.dropna(subset=['reviews'], inplace=True)
    print(file)
    print(len(df))
    for i in range(len(df['reviews'])):
        buffer = requests.get(df['reviews'].iloc[i]).json()
        location = df['location'].iloc[i]
        category = df['category'].iloc[i]
        #subcat = df['subCategory'].iloc[i]
        lat = df['lat'].iloc[i]
        lng = df['lng'].iloc[i]
        for x in buffer:
            if x['language'] == 'en':
                x['location'] = location
                x['category'] = category
                x['subcat'] = subcat
                x['lat'] = lat
                x['lng'] = lng
                all_reviews.append(x)
        if i % 100 == 0:
            print(i)
# Out:
# amsterdam-accommodation.csv
# 117
# 0
# 100
# amsterdam-attraction.csv
# 2302
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[37], line 11
#       9 print(len(df))
#      10 for i in range(len(df['reviews'])):
# ---> 11     buffer = requests.get(df['reviews'].iloc[i]).json()
#      12     location = df['location'].iloc[i]
#      13     category = df['category'].iloc[i]
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
